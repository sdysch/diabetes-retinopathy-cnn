# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import PIL

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train = pd.read_csv('../input/diabetic-retinopathy-detection/trainLabels.csv.zip') 
patient_id = train['image'].str.split('_', n=1, expand=True)
train['patient_id'] = patient_id[0].head()
train['eye']        = patient_id[1].head()
train.drop(['image'], inplace=True, axis=1)
# Out:
#    level patient_id    eye
# 0      0         10   left
# 1      0         10  right
# 2      0         13   left
# 3      0         13  right
# 4      1         15   left

# %%
import zipfile
training_data = [ f'../input/diabetic-retinopathy-detection/train.zip.00{v}' for v in range(1, 6) ]

for file in training_data:
    print(f'Reading {file}')
    with zipfile.ZipFile(file,'r') as z:
        z.extractall('.')
        # save all files to kaggle/files/images
        destination = '/kaggle/images/train'
        z.extractall(destination)
# Out:
# Reading ../input/diabetic-retinopathy-detection/train.zip.001
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# /tmp/ipykernel_34/1363699386.py in <module>
#       4 for file in training_data:
#       5     print(f'Reading {file}')
# ----> 6     with zipfile.ZipFile(file,'r') as z:
#       7         z.extractall('.')
#       8         # save all files to kaggle/files/images
#
# /opt/conda/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1256         try:
#    1257             if mode == 'r':
# -> 1258                 self._RealGetContents()
#    1259             elif mode in ('w', 'x'):
#    1260                 # set the modified flag so central directory gets written
#
# /opt/conda/lib/python3.7/zipfile.py in _RealGetContents(self)
#    1323             raise BadZipFile("File is not a zip file")
# ...
